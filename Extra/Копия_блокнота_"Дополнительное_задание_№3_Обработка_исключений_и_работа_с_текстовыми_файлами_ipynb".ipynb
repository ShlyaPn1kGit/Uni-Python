# %% [markdown]
# <a href="https://colab.research.google.com/github/ShlyaPn1kGit/Uni-Python/blob/main/Extra/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%94%D0%BE%D0%BF%D0%BE%D0%BB%D0%BD%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%BE%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%E2%84%963_%D0%9E%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0_%D0%B8%D1%81%D0%BA%D0%BB%D1%8E%D1%87%D0%B5%D0%BD%D0%B8%D0%B9_%D0%B8_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%D1%81_%D1%82%D0%B5%D0%BA%D1%81%D1%82%D0%BE%D0%B2%D1%8B%D0%BC%D0%B8_%D1%84%D0%B0%D0%B9%D0%BB%D0%B0%D0%BC%D0%B8_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Дополнительное задание №3. Обработка исключений и работа с текстовыми файлами**

# %% [markdown]
# **БАЗА:**
#
# - **Обработка исключений** позволяет перехватывать и обрабатывать ошибки, возникающие при выполнении программы, предотвращая её аварийное завершение.
# - **Работа с файлами** - важный навык для чтения, записи и обработки текстовой информации в Python.
#
# ---

# %% [markdown]
# ## **I. Обработка исключений**

# %% [markdown]
# ### **Пункт №1. Обработка некорректного индекса (IndexError)**

# %% [markdown]
# Создайте список из нескольких элементов (например, [10, 20, 30]). Попросите пользователя ввести индекс элемента, который нужно вывести. Если пользователь введёт индекс, выходящий за границы списка, перехватите IndexError и сообщите об этом.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте список из минимум 5 элементов
# - Покажите содержимое списка перед работой
# - Протестируйте минимум 4 случая (корректный индекс, отрицательный, слишком большой, нечисловое значение)

# %%
s = [10, 20, 30, 40, 50]
for i in range(4):
  print(s)
  try:
    print(s[int(input())])
  except Exception as e:
      print(f"Произошла ошибка {e}")
# Out:
# [10, 20, 30, 40, 50]
# 2
# 30
# [10, 20, 30, 40, 50]
# -6
# Произошла ошибка list index out of range
# [10, 20, 30, 40, 50]
# 20
# Произошла ошибка list index out of range
# [10, 20, 30, 40, 50]
# asd
# Произошла ошибка invalid literal for int() with base 10: 'asd'

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №2. Обработка исключений в цикле**

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя числа и добавляет их в список.
# - Если пользователь вводит некорректные данные, программа должна выводить сообщение об ошибке и продолжать работу.
# - Для выхода из программы пользователь должен ввести "стоп".
#
# **ОБЯЗАТЕЛЬНО:**
# - Покажите процесс ввода минимум 7 значений (включая ошибочные)
# - Выведите финальный список и статистику (сколько чисел введено успешно, сколько ошибок)

# %% [markdown]
# ```
# # Пример:
# # Введите число: 10
# # Введите число: текст (Ошибка: это не число)
# # Введите число: стоп
# # Итоговый список: [10]
# ```

# %%
s = []
e = 0
while True:
  try:
    n = input("Введите число: ")
    if n == "стоп":
      break
    s.append(int(n))
  except ValueError:
    e += 1
    print("Ошибка: Это не число")
print(f'Итоговый список {s}, успешно принято значений - {len(s)}, ошибок - {e}')
# Out:
# Введите число: 10
# Введите число: 20
# Введите число: 30
# Введите число: 20
# Введите число: 10
# Введите число: 40
# Введите число: текст
# Ошибка: Это не число
# Введите число: Почему это не число
# Ошибка: Это не число
# Введите число: Ладно
# Ошибка: Это не число
# Введите число: стоп
# Итоговый список [10, 20, 30, 20, 10, 40], успешно принято значений - 6, ошибок - 3

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №3**

# %% [markdown]
# Создайте функцию `get_list_element(lst, index)`, которая безопасно извлекает элемент списка по индексу с использованием блоков `try`, `except`, `else` и `finally`.
#
# Функция должна:
# - Обрабатывать выход за пределы списка
# - Обрабатывать некорректный тип индекса
# - Выводить сообщение о попытке доступа в блоке `finally`
#
# **ОБЯЗАТЕЛЬНО:**
# - Выведите результаты для минимум 4 различных случаев (успешный доступ, выход за границы, отрицательный индекс, нечисловой индекс)
# - Покажите, что блок `finally` выполняется всегда
#
# ```python
# # Пример использования:
# my_list = [1, 2, 3, 4, 5]
# get_list_element(my_list, 2)   # Вывод: "Элемент: 3", "Попытка доступа завершена"
# get_list_element(my_list, 10)  # Вывод: "Индекс вне диапазона", "Попытка доступа завершена"
# ```

# %%
def get_list_element(lst, index):
  try:
    r = lst[index]
  except IndexError:
    print("Индекс вне диапазона")
  else:
    print(f'Элемент {r}')
  finally:
    print("Попытка доступа завершена")


my_list = [1, 2, 3, 4, 5]
get_list_element(my_list, 2)
get_list_element(my_list, 10)
# Out:
# Элемент 3
# Попытка доступа завершена
# Индекс вне диапазона
# Попытка доступа завершена

# %% [markdown]
# ---

# %% [markdown]
# ## **II. Работа с текстовыми файлами**

# %% [markdown]
# ### **Пункт №1. Запись в файл**

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя строку и записывает её в файл output.txt в режиме дозаписи.
#
# **ОБЯЗАТЕЛЬНО:**
# - Запросите у пользователя минимум 3 строки
# - Покажите содержимое файла после записи

# %%
with open('output.txt', 'a', encoding='utf-8') as f:
  for i in range(4):
    n = input()
    f.write(n + '\n')
  f.close()
print("Содержимое файла после записи:")
with open('output.txt', 'r', encoding='utf-8') as f:
  print(f.read())
  f.close()
# Out:
# is this
# considered
# a text
# file?
# Содержимое файла после записи:
# this is called text
# it is not numerical
# nor is it sound
# it is just plain text
# is
# this
# a
# text file?
# is this
# considered
# a text
# file?

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №2. Чтение из файла**

# %% [markdown]
# Напишите программу, которая открывает файл output.txt и выводит его содержимое на экран.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте файл с минимум 5 строками текста
# - Покажите содержимое файла целиком
# - Обработайте случай отсутствующего файла

# %%
with open('output.txt', 'r', encoding='utf-8') as f:
  try:
    print(f.read())
  except Exception:
    print("Такого файла нет!")
  f.close()
# Out:
# yes, this is a text file
# yes, it is not an image
# yes, it is not an application
# no, you cannot delete this
# dont

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №3. Подсчет строк в файле**

# %% [markdown]
# Напишите программу, которая открывает файл output.txt и подсчитывает количество строк в нём.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте тестовый файл с известным количеством строк (минимум 10)
# - Покажите первые 3 строки файла
# - Выведите общее количество строк
# - Выведите количество непустых строк

# %%
with open('output.txt', 'r', encoding='utf-8') as f:
  s = [x.replace('\n', '') for x in f]
  e = s.count('')
  print(f'Первые три строки - {s[0]}, {s[1]} и {s[2]}')
  print(f'Всего строк - {len(s)}')
  print(f'Непустых строк - {len(s)-e}')
f.close()
# Out:
# Первые три строки - this is, a text file и why is it a text file
# Всего строк - 12
# Непустых строк - 9

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №4. Копирование содержимого файла**

# %% [markdown]
# Напишите программу, которая копирует содержимое файла input.txt в файл output.txt.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте исходный файл с тестовым содержимым (минимум 5 строк)
# - Покажите содержимое исходного файла
# - Выполните копирование
# - Покажите содержимое скопированного файла
# - Обработайте случай отсутствия исходного файла

# %%
with open('input.txt', 'r', encoding='utf-8') as f:
  with open('output.txt', 'w', encoding='utf-8') as r:
    try:
      s = [x for x in f]
      for i in s:
        r.write(i)
      print(f'Исходный файл - {s}')
    except Exception:
      print("Нет исходного файла!")
  r.close()
f.close()

with open('output.txt', 'r', encoding='utf-8') as r:
  print(f'Копированный файл - {r.read()}')
r.close()
# Out:
# Исходный файл - ['this is a dummy file\n', 'it doesnt have any value\n', 'its just text\n', 'and i will copy it\n', 'into output.txt\n']
# Копированный файл - this is a dummy file
# it doesnt have any value
# its just text
# and i will copy it
# into output.txt

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №5. Поиск слова в файле**

# %% [markdown]
# Напишите программу, которая открывает файл output.txt и проверяет, содержится ли в нём слово, введённое пользователем.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте файл с минимум 10 строками текста
# - Покажите содержимое файла
# - Протестируйте поиск минимум 5 различных слов
# - Выведите номера строк, где найдено слово
# - Покажите количество вхождений слова

# %%
with open('output.txt', 'r', encoding='utf-8') as f:
  with open('output.txt', 'r', encoding='utf-8') as r:
    print(r.read())
  r.close()
  s = [x for x in f]
  for i in range(5):
    f_i = set()
    c = 0
    n = input()
    for j in range(len(s)):
      if n in s[j]:
        f_i.add(j)
        c += 1
    if c == 0:
      print("Слово не обнаружено в этом файле")
    else:
      print(f'{n} найдено в строках {f_i} ровно {c} раз')
# Out:
# we got
# bananas
# and apples
# and bananas again
# and oranges
# no peaches
# some oranges again
# carrots
# tomatoes
# and thats it
#
# bananas
# bananas найдено в строках {1, 3} ровно 2 раз
# and
# and найдено в строках {9, 2, 3, 4} ровно 4 раз
# no
# no найдено в строках {5} ровно 1 раз
# thats
# thats найдено в строках {9} ровно 1 раз
# they
# Слово не обнаружено в этом файле

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №6. Чтение файла с обработкой FileNotFoundError**

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя имя файла и пытается открыть его. Если файла не существует, перехватите FileNotFoundError и выведите сообщение «Файл не найден!».
#
# **ОБЯЗАТЕЛЬНО:**
# - Протестируйте с существующим файлом
# - Протестируйте с несуществующим файлом
# - Покажите содержимое существующего файла

# %%
with open('output.txt', 'w', encoding='utf-8') as f:
  f.write('This is a text file \nIt is supposed to be text \nIt better be text')
f.close()
for i in range(2):
  n = input("Введите название файла для открытия: ")
  try:
    with open(n, 'r', encoding='utf-8') as r:
      print(r.read())
  except FileNotFoundError:
    print("Такого файла не существует!")
# Out:
# Введите название файла для открытия: output.txt
# This is a text file
# It is supposed to be text
# It better be text
# Введите название файла для открытия: not_a_file.txt
# Такого файла не существует!

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №7. Подсчет статистики файла**

# %% [markdown]
# Напишите функцию `file_statistics(filename)`, которая читает текстовый файл и возвращает словарь со статистикой:
# - Количество строк
# - Количество слов
# - Количество символов (с пробелами и без)
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте тестовый файл с минимум 5 строками текста
# - Выведите содержимое файла ДО обработки
# - Выведите полученную статистику
# - Обработайте случай несуществующего файла
#
# ```python
# # Создание тестового файла
# test_content = """Первая строка текста
# Вторая строка с большим количеством слов
# Третья строка
# Четвертая строка для теста
# Пятая и последняя строка"""
#
# # Сохраните в файл и продемонстрируйте работу
# ```

# %%
with open("test_content.txt", 'w', encoding='utf-8') as f:
  f.write('This is a header\n')
  f.write('This is a smaller header but i cant really make it smaller\n')
  f.write('Even more text\n')
  f.write('Just a litte more text\n')
  f.write('Okay thats enough\n')


def file_statistics(filename):
  try:
    with open(filename, 'r', encoding='utf-8') as f:
      s = [x for x in f]
      c_w = 0
      c_s = 0
      c_ws = 0
      for x in s:
        r = x.split()
        c_w += len(r)
        c_s += len(x)
        c_ws += len(x.replace(' ', ''))
      print(f'Количество строк - {len(s)}, Количество слов - {c_w}, Количество символов - {c_s} (Без пробелов - {c_ws})')
  except FileExistsError:
    print("Такого файла нет")


file_statistics('test_content.txt')
# Out:
# Количество строк - 5, Количество слов - 27, Количество символов - 132 (Без пробелов - 110)

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №8. Поиск и замена в файле**

# %% [markdown]
# Напишите функцию `replace_in_file(filename, old_text, new_text)`, которая заменяет все вхождения `old_text` на `new_text` в файле и сохраняет результат в новый файл с префиксом "modified_".
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте файл с текстом, содержащим минимум 3 вхождения заменяемого слова
# - Выведите содержимое файла ДО замены
# - Выполните замену
# - Выведите содержимое файла ПОСЛЕ замены
# - Покажите количество произведенных замен

# %%
with open("old_text.txt", 'w', encoding='utf-8') as f:
  f.write('This is a header\n')
  f.write('This is a smaller header but i cant really make it smaller\n')
  f.write('Okay that is enough\n')


def file_replace(filename, old_text, new_text):
  c_r = 0
  with open(f'modified_{filename}', 'w', encoding='utf-8') as new_f:
      with open(filename, 'r', encoding='utf-8') as f:
        s = [x for x in f]
        print(f'Старый файл - {s}')
        for x in s:
          x = x.replace(f' {old_text} ', f' {new_text} ')
          c_r += 1
          new_f.write(x)
        f.close()
      new_f.close()
  with open(f'modified_{filename}', 'r', encoding='utf-8') as new_f:
    print(new_f.read())
    print(f'Произведено замен - {c_r}')


file_replace("old_text.txt", "is", "was")
# Out:
# Старый файл - ['This is a header\n', 'This is a smaller header but i cant really make it smaller\n', 'Okay that is enough\n']
# This was a header
# This was a smaller header but i cant really make it smaller
# Okay that was enough
#
# Произведено замен - 3

# %% [markdown]
# ---

# %% [markdown]
# ### **Пункт №9. Объединение файлов**

# %% [markdown]
# Создайте функцию `merge_files(file_list, output_file)`, которая объединяет содержимое нескольких текстовых файлов в один, добавляя после каждого разделитель.
#
# **ОБЯЗАТЕЛЬНО:**
# - Создайте минимум 3 файла с разным содержимым
# - Выведите содержимое КАЖДОГО исходного файла
# - Выполните объединение
# - Выведите содержимое результирующего файла

# %%
with open("first_file.txt", 'w', encoding='utf-8') as f:
  f.write('This is the first text file\n')
f.close()

with open("second_file.txt", 'w', encoding='utf-8') as f:
  f.write('This is the second text file\n')
f.close()

with open("third_file.txt", 'w', encoding='utf-8') as f:
  f.write('This is the third text file\n')
f.close()


def merge_files(file_list, output_file):
  with open(output_file, 'w', encoding='utf-8') as new_f:
    for x in file_list:
      with open(x, 'r', encoding='utf-8') as f:
        s = [x for x in f]
        print(f"Содержимое файла {x} - {s}")
        for i in s:
            new_f.write(i)
      new_f.write('--------------------\n')
  with open(output_file, 'r', encoding='utf-8') as new_f:
    print('Содержимое общего файла:')
    print(new_f.read())


merge_files(['first_file.txt', 'second_file.txt', 'third_file.txt'], 'output_file.txt')
# Out:
# Содержимое файла first_file.txt - ['This is the first text file\n']
# Содержимое файла second_file.txt - ['This is the second text file\n']
# Содержимое файла third_file.txt - ['This is the third text file\n']
# Содержимое общего файла:
# This is the first text file
# --------------------
# This is the second text file
# --------------------
# This is the third text file
# --------------------

# %% [markdown]
# ---
